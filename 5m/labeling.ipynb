# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Split data

# %%
data_path = 'XAU_5m_data.csv'
save_dir = '.'

# %%
df = pd.read_csv(data_path, sep=';')

# %%
df
# Out:
#                      Date     Open     High      Low    Close  Volume
# 0        2004.06.11 07:15   384.00   384.10   384.00   384.00       3
# 1        2004.06.11 07:20   384.10   384.10   383.80   383.80       3
# 2        2004.06.11 07:25   383.80   384.30   383.80   384.30       6
# 3        2004.06.11 07:30   383.80   383.80   383.80   383.80       2
# 4        2004.06.11 07:35   383.80   384.30   383.60   383.80       6
# ...                   ...      ...      ...      ...      ...     ...
# 1377630  2025.01.31 23:45  2799.62  2801.12  2799.62  2800.90     159
# 1377631  2025.01.31 23:50  2800.90  2802.11  2800.37  2800.62     155
# 1377632  2025.01.31 23:55  2799.68  2800.06  2799.23  2799.23      19
# 1377633  2025.02.03 12:35  2794.58  2795.01  2794.21  2794.31    1199
# 1377634  2025.02.03 12:40  2794.30  2794.54  2794.21  2794.43     426
#
# [1377635 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1377635 entries, 0 to 1377634
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Date    1377635 non-null  object
#  1   Open    1377635 non-null  float64
#  2   High    1377635 non-null  float64
#  3   Low     1377635 non-null  float64
#  4   Close   1377635 non-null  float64
#  5   Volume  1377635 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 63.1+ MB

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values(['Date'], ascending=True)
# df['Year'], df['Month'], df['Day'] = df['Date'].dt.year, df['Date'].dt.month, df['Date'].dt.day

# %%
df
# Out:
#                        Date     Open     High      Low    Close  Volume
# 0       2004-06-11 07:15:00   384.00   384.10   384.00   384.00       3
# 1       2004-06-11 07:20:00   384.10   384.10   383.80   383.80       3
# 2       2004-06-11 07:25:00   383.80   384.30   383.80   384.30       6
# 3       2004-06-11 07:30:00   383.80   383.80   383.80   383.80       2
# 4       2004-06-11 07:35:00   383.80   384.30   383.60   383.80       6
# ...                     ...      ...      ...      ...      ...     ...
# 1377630 2025-01-31 23:45:00  2799.62  2801.12  2799.62  2800.90     159
# 1377631 2025-01-31 23:50:00  2800.90  2802.11  2800.37  2800.62     155
# 1377632 2025-01-31 23:55:00  2799.68  2800.06  2799.23  2799.23      19
# 1377633 2025-02-03 12:35:00  2794.58  2795.01  2794.21  2794.31    1199
# 1377634 2025-02-03 12:40:00  2794.30  2794.54  2794.21  2794.43     426
#
# [1377635 rows x 6 columns]

# %%
test_df = df.loc[df['Date'].dt.year.isin(range(2022, 2026))]
test_df
# Out:
#                        Date     Open     High      Low    Close  Volume
# 1162633 2022-01-03 01:05:00  1830.63  1831.82  1829.52  1831.65     251
# 1162634 2022-01-03 01:10:00  1831.61  1831.61  1830.48  1830.51     162
# 1162635 2022-01-03 01:15:00  1830.48  1830.76  1829.98  1830.07     128
# 1162636 2022-01-03 01:20:00  1830.07  1830.08  1829.21  1829.32     112
# 1162637 2022-01-03 01:25:00  1829.35  1829.42  1828.99  1829.28     111
# ...                     ...      ...      ...      ...      ...     ...
# 1377630 2025-01-31 23:45:00  2799.62  2801.12  2799.62  2800.90     159
# 1377631 2025-01-31 23:50:00  2800.90  2802.11  2800.37  2800.62     155
# 1377632 2025-01-31 23:55:00  2799.68  2800.06  2799.23  2799.23      19
# 1377633 2025-02-03 12:35:00  2794.58  2795.01  2794.21  2794.31    1199
# 1377634 2025-02-03 12:40:00  2794.30  2794.54  2794.21  2794.43     426
#
# [215002 rows x 6 columns]

# %%
dev_df = df.loc[df['Date'].dt.year == 2021]
dev_df
# Out:
#                        Date     Open     High      Low    Close  Volume
# 1092411 2021-01-04 01:05:00  1909.07  1909.33  1907.73  1908.77     810
# 1092412 2021-01-04 01:10:00  1908.67  1909.47  1907.72  1908.88     391
# 1092413 2021-01-04 01:15:00  1908.84  1909.94  1907.88  1909.54     246
# 1092414 2021-01-04 01:20:00  1909.54  1910.69  1909.10  1909.15     261
# 1092415 2021-01-04 01:25:00  1909.20  1911.33  1909.20  1910.86     213
# ...                     ...      ...      ...      ...      ...     ...
# 1162628 2021-12-31 20:25:00  1826.39  1828.08  1825.49  1827.17     754
# 1162629 2021-12-31 20:30:00  1827.21  1827.68  1826.30  1826.69     423
# 1162630 2021-12-31 20:35:00  1826.70  1827.35  1826.67  1827.27     258
# 1162631 2021-12-31 20:40:00  1827.23  1827.55  1826.73  1827.44     216
# 1162632 2021-12-31 20:45:00  1827.46  1828.04  1827.39  1827.95     158
#
# [70222 rows x 6 columns]

# %%
train_df = df.loc[df['Date'].dt.year.isin(range(2010, 2021))]
train_df
# Out:
#                        Date     Open     High      Low    Close  Volume
# 336714  2010-01-04 01:05:00  1094.61  1095.00  1093.78  1094.36     380
# 336715  2010-01-04 01:10:00  1094.37  1094.70  1093.08  1093.40     364
# 336716  2010-01-04 01:15:00  1093.75  1095.15  1093.35  1095.10     376
# 336717  2010-01-04 01:20:00  1094.95  1095.75  1094.18  1095.30     331
# 336718  2010-01-04 01:25:00  1095.31  1096.45  1095.18  1095.65     313
# ...                     ...      ...      ...      ...      ...     ...
# 1092406 2020-12-31 20:25:00  1890.77  1891.74  1890.40  1891.74     454
# 1092407 2020-12-31 20:30:00  1891.70  1893.14  1891.50  1892.54     346
# 1092408 2020-12-31 20:35:00  1892.56  1893.57  1892.39  1893.49     185
# 1092409 2020-12-31 20:40:00  1893.49  1893.67  1892.96  1893.53     123
# 1092410 2020-12-31 20:45:00  1893.52  1893.54  1893.26  1893.43      79
#
# [755697 rows x 6 columns]

# %%
def get_future_price(df, delta=30):
    df.loc[:, [f'Price_t_plus_{delta}']] = df['Close'].shift(-delta)
    return df

# %%
# cols = ['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Volume', f'Price_t_plus_{delta}']

# train_df[cols].dropna().to_csv('data/regression_train.csv', index=False)
# dev_df[cols].dropna().to_csv('data/regression_dev.csv', index=False)
# test_df[cols].dropna().to_csv('data/regression_test.csv', index=False)

# %% [markdown]
# # Labeling for classification

# %%
# def calculate_threshold(df, delta=30):
#     df = get_future_price(df, delta=30)

#     # Tính tỷ lệ thay đổi giá
#     df.loc[:, ['Return']] = df[f'Price_t_plus_{delta}'] / df['Close'] - 1

#     # Loại bỏ giá trị NaN (do shift)
#     df = df.dropna()

#     # Tách return thành tăng (dương) và giảm (âm)
#     positive_returns = df['Return'][df['Return'] > 0]  # Tăng giá
#     negative_returns = df['Return'][df['Return'] < 0]  # Giảm giá

#     # Thống kê cho return dương (BUY)
#     mean_positive = positive_returns.mean()
#     std_positive = positive_returns.std()
#     percentiles_positive = positive_returns.quantile([0.25, 0.5, 0.75, 0.95])

#     # Thống kê cho return âm (SELL)
#     mean_negative = negative_returns.mean()
#     std_negative = negative_returns.std()
#     percentiles_negative = negative_returns.quantile([0.05, 0.25, 0.5, 0.75])

#     # In thống kê
#     print(f"Thống kê dao động giá trong {delta} phút (Tăng - BUY):")
#     print(f"Trung bình: {mean_positive:.4%}")
#     print(f"Độ lệch chuẩn: {std_positive:.4%}")
#     print(f"Phân vị 25%: {percentiles_positive[0.25]:.4%}")
#     print(f"Phân vị 50% (median): {percentiles_positive[0.5]:.4%}")
#     print(f"Phân vị 75%: {percentiles_positive[0.75]:.4%}")
#     print(f"Phân vị 95%: {percentiles_positive[0.95]:.4%}")

#     print(f"\nThống kê dao động giá trong {delta} phút (Giảm - SELL):")
#     print(f"Trung bình: {mean_negative:.4%}")
#     print(f"Độ lệch chuẩn: {std_negative:.4%}")
#     print(f"Phân vị 5%: {percentiles_negative[0.05]:.4%}")
#     print(f"Phân vị 25%: {percentiles_negative[0.25]:.4%}")
#     print(f"Phân vị 50% (median): {percentiles_negative[0.5]:.4%}")
#     print(f"Phân vị 75%: {percentiles_negative[0.75]:.4%}")

#     # Vẽ histogram riêng cho tăng và giảm
#     plt.figure(figsize=(7, 4))

#     plt.subplot(1, 2, 1)
#     plt.hist(positive_returns, bins=50, range=(0, 0.05), density=True, color='blue')
#     plt.title(f"Phân bố tăng giá (BUY) trong {delta} phút")
#     plt.xlabel("Return")
#     plt.ylabel("Tần suất")

#     plt.subplot(1, 2, 2)
#     plt.hist(negative_returns, bins=50, range=(-0.05, 0), density=True, color='red')
#     plt.title(f"Phân bố giảm giá (SELL) trong {delta} phút")
#     plt.xlabel("Return")
#     plt.ylabel("Tần suất")

#     plt.tight_layout()
#     plt.show()

#     print(f'Delta = {delta}')
    
#     # Đề xuất threshold 
#     threshold = std_positive * 0.45
    
#     print(f"Threshold gợi ý: {threshold:.4%}")
    
#     # Tính giá trị tiền dựa trên giá trung bình trong df
#     avg_price = df['Close'].mean()
#     print(f"\nGiá trung bình trong dữ liệu: ${avg_price:.2f}")

#     # Tính giá trị tiền
#     threshold_in_money = avg_price * threshold

#     print(f"Giá trị tiền tương ứng với threshold:")
#     print(f"Threshold ({threshold}) in money: ${threshold_in_money:.2f}")

#     # Kiểm tra phân bố nhãn với threshold riêng
#     df.loc[:, ['Label']] = np.where(df[f'Price_t_plus_{delta}'] > df['Close'] * (1 + threshold), 'BUY',
#                         np.where(df[f'Price_t_plus_{delta}'] < df['Close'] * (1 - threshold), 'SELL', 'HOLD'))

#     label_distribution = df['Label'].value_counts(normalize=True)
#     print("\nPhân bố nhãn với threshold riêng:")
#     print(label_distribution)
    
#     return df, delta, threshold

# %%
def calculate_threshold(df, delta=30, rate=0.45):
    df = get_future_price(df, delta=delta)

    # Tính tỷ lệ thay đổi giá
    df.loc[:, ['Return']] = df[f'Price_t_plus_{delta}'] / df['Close'] - 1

    # Loại bỏ giá trị NaN (do shift)
    df = df.dropna()

    # Tách return thành tăng (dương) và giảm (âm)
    positive_returns = df['Return'][df['Return'] > 0]  # Tăng giá

    std_positive = positive_returns.std()

    print(f'Delta = {delta}')
    
    # Đề xuất threshold 
    threshold = std_positive * rate # 1.5 lần độ lệch chuẩn cho BUY
    
    print(f"Threshold gợi ý: {threshold:.4%}")
    
    # Tính giá trị tiền dựa trên giá trung bình trong df
    avg_price = df['Close'].mean()
    print(f"\nGiá trung bình trong dữ liệu: ${avg_price:.2f}")

    # Tính giá trị tiền
    threshold_in_money = avg_price * threshold

    print(f"Threshold ({threshold}) thành tiền: ${threshold_in_money:.2f}")
    
    return delta, threshold

# %%
delta, threshold = calculate_threshold(train_df, 6, 0.4)
# Out:
# Delta = 6
# Threshold gợi ý: 0.0450%
#
# Giá trung bình trong dữ liệu: $1385.43
# Threshold (0.0004500385238522182) thành tiền: $0.62

# %%
# Simple labeling
def simple_labeling(df, delta, threshold):
    df.loc[:, [f'Price_t_plus_{delta}']] = df['Close'].shift(-delta)

    # Tính tỷ lệ thay đổi giá
    df.loc[:, ['Return']] = df[f'Price_t_plus_{delta}'] / df['Close'] - 1

    # Loại bỏ giá trị NaN (do shift)
    df = df.dropna()
    
    # Kiểm tra phân bố nhãn với threshold riêng
    df.loc[:, ['Label']] = np.where(df[f'Price_t_plus_{delta}'] > df['Close'] * (1 + threshold), 'BUY',
                        np.where(df[f'Price_t_plus_{delta}'] < df['Close'] * (1 - threshold), 'SELL', 'HOLD'))

    label_distribution = df['Label'].value_counts(normalize=True)
    print("\nPhân bố nhãn với threshold riêng:")
    print(label_distribution)
    
    return df

# %%
labeled_train_df = simple_labeling(train_df, delta, threshold)
# labeled_train_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.422122
# BUY     0.292225
# SELL    0.285652
# Name: proportion, dtype: float64

# %%
labeled_dev_df = simple_labeling(dev_df, delta, threshold)
# labeled_dev_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.418338
# BUY     0.296699
# SELL    0.284964
# Name: proportion, dtype: float64

# %%
labeled_test_df = simple_labeling(test_df, delta, threshold)
# labeled_test_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.418794
# BUY     0.295810
# SELL    0.285396
# Name: proportion, dtype: float64

# %%
labeled_train_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Price_t_plus_6',
#        'Return', 'Label'],
#       dtype='object')

# %%
cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Label']

labeled_train_df[cols].to_csv(f'{save_dir}/labeled_train.csv', index=False)
labeled_dev_df[cols].to_csv(f'{save_dir}/labeled_dev.csv', index=False)
labeled_test_df[cols].to_csv(f'{save_dir}/labeled_test.csv', index=False)

# %%
def counter_label(df, delta):
    cnt = 0
    for i in range(0, len(df) - delta, delta):
        label = df['Label'].iloc[i-30]
        for j in range(i, i+delta):
            if label == 'BUY':
                if df['Label'].iloc[j] == 'SELL':
                    cnt += 1
                    break
            elif label == 'SELL':
                if df['Label'].iloc[j] == 'BUY':
                    cnt += 1
                    break
    return cnt


print("Tong so label: ", len(labeled_train_df))
cnt = counter_label(labeled_train_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(labeled_train_df) * 100)


print("Tong so label: ", len(labeled_dev_df))
cnt = counter_label(labeled_dev_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(labeled_dev_df) * 100)


print("Tong so label: ", len(labeled_test_df))
cnt = counter_label(labeled_test_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(labeled_test_df) * 100)
# Out:
# Tong so label:  755691
# So lan xuat hien nhan nguoc:  44352
# Ti le xuat hien nhan nguoc 5.869065530752649
# Tong so label:  70216
# So lan xuat hien nhan nguoc:  4041
# Ti le xuat hien nhan nguoc 5.755098553036345
# Tong so label:  214996
# So lan xuat hien nhan nguoc:  12472
# Ti le xuat hien nhan nguoc 5.801038158849467

# %% [markdown]
# Tại thời điểm T, xét trong khoảng (T, T + $\Delta$):
# - Nếu T đang là BUY (giá tại T + $\Delta$ cao hơn T), trong khoảng này xuất hiện điểm có giá nhỏ hơn T rất nhiều (đáy $\sqrt{}$)
#         thì nhãn tại T sẽ được chuyển thành SELL.
# - Và ngược lại

# %%
def dynamic_labeling(df, delta, threshold):
    df = df.copy()
    
    # Bước gán nhãn ban đầu
    df = simple_labeling(df, delta, threshold)
    
    # Tính sẵn min/max trong cửa sổ kế tiếp delta dòng => Cực trị
    # Dịch ngược DataFrame, tính rolling min/max, rồi dịch đúng thứ tự
    reversed_close = df['Close'].iloc[::-1]
    rolling_min = reversed_close.rolling(window=delta, min_periods=1).min().iloc[::-1].shift(1)
    rolling_max = reversed_close.rolling(window=delta, min_periods=1).max().iloc[::-1].shift(1)

    # Áp dụng min/max tương ứng từng hàng
    df['future_min'] = rolling_min
    df['future_max'] = rolling_max

    # Cập nhật nhãn theo giá cực trị
    df.loc[(df['Label'] == 'BUY') & (df['future_min'] < df['Close'] * (1 - threshold)), 'Label'] = 'SELL'
    df.loc[(df['Label'] == 'SELL') & (df['future_max'] > df['Close'] * (1 + threshold)), 'Label'] = 'BUY'

    label_distribution = df['Label'].value_counts(normalize=True)
    print("\nPhân bố nhãn sau cập nhật:")
    print(label_distribution)

    return df

# %%
dynamic_labeled_train_df = dynamic_labeling(train_df, delta, threshold)
# dynamic_labeled_train_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.422122
# BUY     0.292225
# SELL    0.285652
# Name: proportion, dtype: float64
#
# Phân bố nhãn sau cập nhật:
# Label
# HOLD    0.422122
# BUY     0.340729
# SELL    0.237149
# Name: proportion, dtype: float64

# %%
dynamic_labeled_dev_df = dynamic_labeling(dev_df, delta, threshold)
# dynamic_labeled_dev_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.418338
# BUY     0.296699
# SELL    0.284964
# Name: proportion, dtype: float64
#
# Phân bố nhãn sau cập nhật:
# Label
# HOLD    0.418338
# BUY     0.344879
# SELL    0.236784
# Name: proportion, dtype: float64

# %%
dynamic_labeled_test_df = dynamic_labeling(test_df, delta, threshold)
# dynamic_labeled_test_df
# Out:
# Phân bố nhãn với threshold riêng:
# Label
# HOLD    0.418794
# BUY     0.295810
# SELL    0.285396
# Name: proportion, dtype: float64
#
# Phân bố nhãn sau cập nhật:
# Label
# HOLD    0.418794
# BUY     0.343676
# SELL    0.237530
# Name: proportion, dtype: float64

# %%
print("Tong so label: ", len(dynamic_labeled_train_df))
cnt = counter_label(dynamic_labeled_train_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(dynamic_labeled_train_df) * 100)


print("Tong so label: ", len(dynamic_labeled_dev_df))
cnt = counter_label(dynamic_labeled_dev_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(dynamic_labeled_dev_df) * 100)


print("Tong so label: ", len(dynamic_labeled_test_df))
cnt = counter_label(dynamic_labeled_test_df, delta)
print("So lan xuat hien nhan nguoc: ", cnt)
print("Ti le xuat hien nhan nguoc", cnt / len(dynamic_labeled_test_df) * 100)
# Out:
# Tong so label:  755691
# So lan xuat hien nhan nguoc:  49973
# Ti le xuat hien nhan nguoc 6.61288807197651
# Tong so label:  70216
# So lan xuat hien nhan nguoc:  4610
# Ti le xuat hien nhan nguoc 6.565455166913524
# Tong so label:  214996
# So lan xuat hien nhan nguoc:  14235
# Ti le xuat hien nhan nguoc 6.621053414947255

# %%
cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Label']

dynamic_labeled_train_df[cols].to_csv(f'{save_dir}/dynamic_labeled_train.csv', index=False)
dynamic_labeled_dev_df[cols].to_csv(f'{save_dir}/dynamic_labeled_dev.csv', index=False)
dynamic_labeled_test_df[cols].to_csv(f'{save_dir}/dynamic_labeled_test.csv', index=False)
